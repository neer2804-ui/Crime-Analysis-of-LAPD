# %% [markdown]
# # LAPD Crime Analysis — Complete Notebook with Outputs
#
# **Executed:** 2026-05-04 08:14:18
#
# **Dataset:** 1,004,991 crime incidents (2020-2025)

# %% [markdown]
# ## SECTION 1: DATA SUMMARY

# %%
# Data Summary
# Out:
# Dataset Overview:
# - Total Incidents: 1,004,991
# - Date Range: 2020-01-01 to 2025-05-29
# - Weapon Usage: 32.6%
# - Most Common Area: Central

# %% [markdown]
# ## SECTION 2: EDA VISUALIZATIONS

# %%
# Top 20 Crimes

# %%
# Crime Categories

# %%
# Monthly Trend

# %%
# Hourly Distribution

# %%
# Day of Week

# %%
# Heatmap

# %% [markdown]
# ## SECTION 3: MACHINE LEARNING

# %%
# Model Training
# Out:
# Model Results:
# Model  Accuracy      AUC
#    LR   0.66455 0.796436
#    RF   0.83980 0.929265
#   XGB   0.85305 0.938659

# %%
# ROC Curves

# %%
# Confusion Matrices

# %% [markdown]
# ## SECTION 4: TIME SERIES FORECASTING

# %%
# Time Series
# Out:
# SARIMA Results:
# MAE: 9906
# RMSE: 11015

# %%
# Decomposition

# %% [markdown]
# ## SECTION 5: NLP ANALYSIS

# %%
# NLP Analysis
# Out:
# NLP Statistics:
# Unique Tokens: 214
# Total Tokens: 2,963,763
#
# Top 10:
# 1. theft: 285,049
# 2. vehicle: 266,591
# 3. assault: 250,753
# 4. vandalism: 147,565
# 5. stolen: 133,714
# 6. petty: 128,194
# 7. simple: 127,674
# 8. burglary: 126,046
# 9. grand: 88,561
# 10. weapon: 88,462

# %%
# Word Cloud

# %%
# Top Words

# %%
# LDA Topics
# Out:
# LDA Topics:
#
# Topic 1: vehicle, stolen, vandalism, theft, petty, felony, burglary, church, motor, shoplifting
#
# Topic 2: vandalism, misdeameanor, trespassing, weapon, brandish, court, order, violation, shot, fired
#
# Topic 3: grand, theft, motor, vehicle, gun, prod, fowl, excpt, livestk, restraining
#
# Topic 4: assault, aggravated, weapon, deadly, robbery, attempted, document, forgery, failure, yield
#
# Topic 5: battery, simple, assault, burglary, lewd, call, letter, telephone, sexual, child
#
# Topic 6: theft, identity, partner, intimate, petty, plain, assault, simple, criminal, displayed
